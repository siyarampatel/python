# %%
# function
# def function_name(a,b->parameters)
# function_name(arguments)
# dynamically typed language
# Variable has no fixed type
# Object has the type
# Type is checked during execution

# %%
# //factorail
n=int(input("give n"))
def factorial(n):
    fact=1;
    for i in range(1,n+1):
        fact*=i
    return fact

result=factorial(n)
print("factorial->",result)
# Out:
# factorial-> 6
