# %%
#empty tuple
tpl=()
trp1=tuple()
print(tpl,trp1)

# %%
tpl=(1);
print(type(tpl))
tpl=();
print(type(tpl))
tpl=(1,2,3);
print(type(tpl))

# %%
#tupple are immutable 
# here the new tupple is created 
tpl=(1,2,5,3,3,"hii")
tpl+=(3,5,3)
print(tpl)

# %%
#tupple can be converteed to list for updation and then again shift to tuple
tpl=(2,3,4,5);
tpl=list(tpl)
tpl[2]=809
tpl=tuple(tpl)
print(tpl)
# Out:
# (2, 3, 809, 5)

# %%
tpl=(4,5,3,4,5,4,3,2,3,4,5,5,4,4,4,4)
print(sorted(tpl,reverse=True))
#this will give output as list not tuple
# Out:
# [5, 5, 5, 5, 4, 4, 4, 4, 4, 4, 4, 4, 3, 3, 3, 2]

# %%
tpl=(1,5,6,4,3,6,7,7,77,1,2)
tpl[-3::-6]
# Out:
# (77, 6)
