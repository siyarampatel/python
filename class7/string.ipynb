# %%
#string are immutable
s1="py"
s2="thon"
s1=s1+s2
print(s1)
# string will multiple itself 4 times
s1*=4;
print(s1)

# %%
print('o' in "hello world")
# checks if an character present or not

# %%
v="SDFAS";
n=v.lower()
print(n)
# no changes done in real string

# %%
# for changes change string to list
s="global is the best"
l=s.split()#it will change the string to list by breaking it from spaces
print(l)

# %%
s="global is the best"
l=s.split(sep='o')#it will change the string to list by breaking it from 'o'
print(l)
# Out:
# ['gl', 'bal is the best']

# %%
words = ["Hello", "World"]
result = " ".join(words)
print(result)
# Out:
# Hello World
