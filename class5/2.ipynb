# %%
# eval function is used when we have to give the input of our choice
l=eval(input())
print(type(l))
print(l)

# %%
l=[8,10,12,13,15,10]
for i in range(len(l)):
    if l[i]%2==0:
        l[i]+=5
    else:
        l[i]-=5
print(l);
