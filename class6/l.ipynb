# %%
l=[1,2,3,4,5,6]
l.reverse();
print(l)
# Out:
# [6, 5, 4, 3, 2, 1]

# %%
l=[5,6,8,5,6,4,5,6,7,]
l.sort()
print(l)
# Out:
# [4, 5, 5, 5, 6, 6, 6, 7, 8]

# %%
l=[5,6,8,5,6,4,5,6,7,]
l.sort(reverse=True)
print(l)
# Out:
# [8, 7, 6, 6, 6, 5, 5, 5, 4]

# %%
l=[5,6,8,5,6,4,5,6,7,]
l1=sorted(l)
print(l1)
# Out:
# [4, 5, 5, 5, 6, 6, 6, 7, 8]
