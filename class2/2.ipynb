# %%
a=9
b=2
print(a/b)
print(a//b)
print(a**b)

# %%
age=int(input("Enter age:"))
if age>=18:
    print("You are eligible for voting process.")
else:
    print("Not eligible.")

# %%
n=int(input("Enter n:"))
if n%2==0:
    print("It's an even number")
else:
    print("Odd")

# %%
n=int(input("Enter number:"))
if (n%4==0 and n%100!=0)or(n%400==0):
    print("It's an leap year")
else:
    print("Not an leap year")
# Out:
# Not an leap year
