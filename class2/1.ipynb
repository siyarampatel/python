# %%
# write a program which will take l and b as input and print area of rec.
length=int(input("Enter length of rectangle"))
bredth=int(input("Enter bredth"))
if(length<=0 or bredth<=0):
    print("length and bredth can't be zero and negative")

else: 
    print("The area of rectangle is:",length*bredth)

# %%
a=8
print(type(a))

# %%
radius=float(input("Enter radius"))
if radius<=0:
    print("Invalid input")
else:
    print("The area of circle is:",3.14*radius*radius)
    print("The circumference of circle is:",2*3.14*radius)
