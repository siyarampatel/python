# %%
s="Hello everyone lets learn python"
l=s.split();
l.sort(reverse=True)
result = " ".join(l)
print(result)

# %%
s="Hello everyone lets learn python"
l=s.split();
l.sort(reverse=True)
for i in range (len(l)):
    l[i]=l[i][::-1]
result = " ".join(l)
print(result)
